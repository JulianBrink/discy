# %% [markdown]
# ## SQL reader

# %%
import sqlalchemy as sqla
import pandas as pd
from sqlalchemy.orm import declarative_base
from sqlalchemy.orm import Session
import sql_reader as sqr

# %%
layout_versions = sqr.get_table_layout_versions()
layout_versions
# Out:
# 2021-08-12 11:18:45,680 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2021-08-12 11:18:45,681 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:18:45,683 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='view' ORDER BY name
# 2021-08-12 11:18:45,683 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:18:45,685 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("layout_versions")
# 2021-08-12 11:18:45,686 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:18:45,689 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-08-12 11:18:45,690 INFO sqlalchemy.engine.Engine [raw sql] ('layout_versions',)
# 2021-08-12 11:18:45,692 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("layout_versions")
# 2021-08-12 11:18:45,692 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:18:45,693 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-08-12 11:18:45,694 INFO sqlalchemy.engine.Engine [raw sql] ('layout_versions',)
# 2021-08-12 11:18:45,695 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("layouts")
# 2021-08-12 11:18:45,696 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:18:45,697 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-08-12 11:18:45,698 INFO sqlalchemy.engine.Engine [raw sql] ('layouts',)
# 2021-08-12 11:18:45,699 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("layouts")
# 2021-08-12 11:18:45,700 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:18:45,701 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-08-12 11:18:45,701 INFO sqlalchemy.engine.Engine [raw sql] ('layouts',)
# 2021-08-12 11:18:45,703 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("courses")
# 2021-08-12 11:18:45,703 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:18:45,705 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-08-12 11:18:45,705 INFO sqlalchemy.engine.Engine [raw sql] ('courses',)
# 2021-08-12 11:18:45,706 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("courses")
# 2021-08-12 11:18:45,707 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:18:45,708 INFO sqlalchemy.engine.Engine PRAGMA temp.foreign_key_list("courses")
# 2021-08-12 11:18:45,709 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:18:45,710 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-08-12 11:18:45,711 INFO sqlalchemy.engine.Engine [raw sql] ('courses',)
# 2021-08-12 11:18:45,712 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("courses")
# 2021-08-12 11:18:45,713 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:18:45,715 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("courses")
# 2021-08-12 11:18:45,715 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:18:45,717 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("sqlite_autoindex_courses_1")
# 2021-08-12 11:18:45,717 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:18:45,718 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-08-12 11:18:45,719 INFO sqlalchemy.engine.Engine [raw sql] ('courses',)
# 2021-08-12 11:18:45,721 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("layouts")
# 2021-08-12 11:18:45,721 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:18:45,722 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("layouts")
# 2021-08-12 11:18:45,723 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:18:45,724 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("sqlite_autoindex_layouts_1")
# 2021-08-12 11:18:45,724 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:18:45,726 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-08-12 11:18:45,727 INFO sqlalchemy.engine.Engine [raw sql] ('layouts',)
# 2021-08-12 11:18:45,729 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("layout_versions")
# 2021-08-12 11:18:45,730 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:18:45,731 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("layout_versions")
# 2021-08-12 11:18:45,732 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:18:45,733 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("sqlite_autoindex_layout_versions_1")
# 2021-08-12 11:18:45,733 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:18:45,735 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-08-12 11:18:45,735 INFO sqlalchemy.engine.Engine [raw sql] ('layout_versions',)
# 2021-08-12 11:18:45,742 INFO sqlalchemy.engine.Engine SELECT layout_versions.version, layout_versions.course_name, layout_versions.layout_name, layout_versions.oldest, layout_versions.newest, layout_versions.holes, layout_versions.par
# FROM layout_versions
# 2021-08-12 11:18:45,743 INFO sqlalchemy.engine.Engine [generated in 0.00141s] ()
#     version                      course_name  \
# 0         1   D.C.O.Z; Bring your own target
# 1         1               Dietenbach Headsup
# 2         1               Dietenbach Headsup
# 3         1               Fröttmaninger Berg
# 4         1         Golfcourse at The Gögerl
# 5         1                          Kurpark
# 6         1                       Königsfeld
# 7         1     Bochum Volkspark Langendreer
# 8         1                 D.C.O.Z Mannheim
# 9         1          Darmstadt TU-Lichtwiese
# 10        1  Dortmund Revierpark Wischlingen
# 11        1              Herne Gysenbergpark
# 12        1              Lünen Alte Ziegelei
# 13        1                    Lünen Seepark
# 39                                           Main  2020-09-11 10:31
# 40                                           Main  2018-08-31 12:08
# 41                  5. Wesel Borderline Shop Open  2019-10-12 09:30
# 42                                         NORMAL  2019-07-28 15:45
# 43                                        Special  2019-04-07 10:36
# 44                               Kellenhusen Kurz  2020-07-10 20:14
# 45                                           Main  2020-07-11 19:09
# 46                                    Family 2016  2019-03-05 09:18
# 47                                           Main  2020-11-15 15:17
#
#               newest  holes  par
# 0   2020-12-28 14:51      7   21
# 1   2020-11-22 13:33     18   57
# 2   2020-10-25 16:09      9   27
# 3   2020-09-07 19:08      8   25
# 4   2021-03-07 13:58     18   54
# 5   2020-11-27 16:19      9   28
# 6   2020-12-23 15:19      9   29
# 7   2019-07-31 19:18     10   30
# 8   2021-01-01 14:05      9   27
# 9   2020-12-31 12:06     18   57
# 10  2021-02-23 16:00     18   55
# 11  2021-03-02 15:27      9   27
# 12  2020-12-05 13:56     13   40
# 13  2020-12-05 10:19     12   37
# 14  2020-12-05 15:35     12   37
# 15  2018-11-04 15:44      9   28
# 16  2021-01-02 13:51     18   55
# 17  2019-07-13 15:10     12   37
# 18  2019-09-14 14:50     12   36
# 19  2019-03-09 15:15     12   38
# 20  2019-03-30 13:00     18   56
# 21  2020-10-18 13:15     18   55
# 22  2019-08-31 14:20     20   66
# 23  2019-11-09 14:30     12   38
# 24  2019-08-17 12:40      9   28
# 25  2020-10-03 14:15      9   27
# 26  2020-10-03 10:39      9   27
# 27  2020-09-06 16:42     12   37
# 28  2019-07-20 16:21     18   56
# 29  2020-11-28 14:10     12   38
# 30  2019-12-14 13:45     12   36
# 31  2020-06-24 17:23     12   37
# 32  2019-06-08 14:45     12   36
# 33  2019-09-07 13:25     18   60
# 34  2020-09-09 17:43      9   28
# 35  2019-02-09 14:45     12   38
# 36  2019-09-22 13:45     18   55
# 37  2020-08-30 12:30     18   59
# 38  2019-08-10 14:15     12   36
# 39  2020-09-11 10:31     18   59
# 40  2019-07-24 12:52     18   58
# 41  2019-10-12 13:30     18   55
# 42  2021-03-24 17:44     10   32
# 43  2019-04-07 10:36     12   37
# 44  2020-07-10 20:14     10   30
# 45  2020-07-11 19:09     22   67
# 46  2019-03-05 09:18     10   30
# 47  2021-03-07 15:34      9   30

# %%
engine = sqla.create_engine('sqlite+pysqlite:///../data/discy.db', echo=True)

# %%
metadata = sqla.MetaData()

Base = declarative_base()

# %%
courses = sqla.Table("courses", metadata, autoload_with=engine)
layouts = sqla.Table("layouts", metadata, autoload_with=engine)
layout_versions = sqla.Table("layout_versions", metadata, autoload_with=engine)
scoredata = sqla.Table("scoredata", metadata, autoload_with=engine)
# Out:
# 2021-08-12 11:16:04,289 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("courses")
# 2021-08-12 11:16:04,291 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:16:04,293 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-08-12 11:16:04,294 INFO sqlalchemy.engine.Engine [raw sql] ('courses',)
# 2021-08-12 11:16:04,296 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("courses")
# 2021-08-12 11:16:04,297 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:16:04,298 INFO sqlalchemy.engine.Engine PRAGMA temp.foreign_key_list("courses")
# 2021-08-12 11:16:04,300 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:16:04,301 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-08-12 11:16:04,301 INFO sqlalchemy.engine.Engine [raw sql] ('courses',)
# 2021-08-12 11:16:04,304 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("courses")
# 2021-08-12 11:16:04,305 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:16:04,307 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("courses")
# 2021-08-12 11:16:04,307 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:16:04,309 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("sqlite_autoindex_courses_1")
# 2021-08-12 11:16:04,309 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:16:04,310 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-08-12 11:16:04,311 INFO sqlalchemy.engine.Engine [raw sql] ('courses',)
# 2021-08-12 11:16:04,316 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("layouts")
# 2021-08-12 11:16:04,316 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:16:04,318 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-08-12 11:16:04,319 INFO sqlalchemy.engine.Engine [raw sql] ('layouts',)
# 2021-08-12 11:16:04,321 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("layouts")
# 2021-08-12 11:16:04,321 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:16:04,323 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-08-12 11:16:04,324 INFO sqlalchemy.engine.Engine [raw sql] ('layouts',)
# 2021-08-12 11:16:04,326 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("layouts")
# 2021-08-12 11:16:04,327 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:16:04,328 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("layouts")
# 2021-08-12 11:16:04,328 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:16:04,330 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("sqlite_autoindex_layouts_1")
# 2021-08-12 11:16:04,331 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:16:04,332 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-08-12 11:16:04,333 INFO sqlalchemy.engine.Engine [raw sql] ('layouts',)
# 2021-08-12 11:16:04,336 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("layout_versions")
# 2021-08-12 11:16:04,338 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:16:04,341 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-08-12 11:16:04,341 INFO sqlalchemy.engine.Engine [raw sql] ('layout_versions',)
# 2021-08-12 11:16:04,343 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("layout_versions")
# 2021-08-12 11:16:04,344 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:16:04,345 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-08-12 11:16:04,346 INFO sqlalchemy.engine.Engine [raw sql] ('layout_versions',)
# 2021-08-12 11:16:04,348 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("layout_versions")
# 2021-08-12 11:16:04,349 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:16:04,351 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("layout_versions")
# 2021-08-12 11:16:04,351 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:16:04,353 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("sqlite_autoindex_layout_versions_1")
# 2021-08-12 11:16:04,353 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:16:04,355 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-08-12 11:16:04,356 INFO sqlalchemy.engine.Engine [raw sql] ('layout_versions',)
# 2021-08-12 11:16:04,359 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("scoredata")
# 2021-08-12 11:16:04,360 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:16:04,363 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-08-12 11:16:04,363 INFO sqlalchemy.engine.Engine [raw sql] ('scoredata',)
# 2021-08-12 11:16:04,366 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("scoredata")
# 2021-08-12 11:16:04,368 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:16:04,369 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-08-12 11:16:04,370 INFO sqlalchemy.engine.Engine [raw sql] ('scoredata',)
# 2021-08-12 11:16:04,373 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("scoredata")
# 2021-08-12 11:16:04,373 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:16:04,375 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("scoredata")
# 2021-08-12 11:16:04,376 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:16:04,377 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("sqlite_autoindex_scoredata_1")
# 2021-08-12 11:16:04,378 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-08-12 11:16:04,379 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-08-12 11:16:04,380 INFO sqlalchemy.engine.Engine [raw sql] ('scoredata',)

# %%
courses
# Out:
# Table('courses', MetaData(), Column('course_name', VARCHAR(), table=<courses>, primary_key=True, nullable=False), schema=None)

# %%
layouts
# Out:
# Table('layouts', MetaData(), Column('layout_name', VARCHAR(), table=<layouts>, primary_key=True, nullable=False), Column('course_name', VARCHAR(), ForeignKey('courses.course_name'), table=<layouts>, primary_key=True, nullable=False), schema=None)

# %%
layout_versions
# Out:
# Table('layout_versions', MetaData(), Column('version', INTEGER(), table=<layout_versions>, primary_key=True, nullable=False), Column('layout_name', VARCHAR(), ForeignKey('layouts.layout_name'), table=<layout_versions>, primary_key=True, nullable=False), Column('course_name', VARCHAR(), ForeignKey('layouts.course_name'), table=<layout_versions>, primary_key=True, nullable=False), Column('oldest', VARCHAR(), table=<layout_versions>, nullable=False), Column('newest', VARCHAR(), table=<layout_versions>, nullable=False), Column('holes', INTEGER(), table=<layout_versions>, nullable=False), Column('par', INTEGER(), table=<layout_versions>, nullable=False), Column('h1', INTEGER(), table=<layout_versions>), Column('h2', INTEGER(), table=<layout_versions>), Column('h3', INTEGER(), table=<layout_versions>), Column('h4', INTEGER(), table=<layout_versions>), Column('h5', INTEGER(), table=<layout_versions>), Column('h6', INTEGER(), table=<layout_versions>), Column('h7', INTEGER(), table=<layout_versions>), Column('h8', INTEGER(), table=<layout_versions>), Column('h9', INTEGER(), table=<layout_versions>), Column('h10', INTEGER(), table=<layout_versions>), Column('h11', INTEGER(), table=<layout_versions>), Column('h12', INTEGER(), table=<layout_versions>), Column('h13', INTEGER(), table=<layout_versions>), Column('h14', INTEGER(), table=<layout_versions>), Column('h15', INTEGER(), table=<layout_versions>), Column('h16', INTEGER(), table=<layout_versions>), Column('h17', INTEGER(), table=<layout_versions>), Column('h18', INTEGER(), table=<layout_versions>), Column('h19', INTEGER(), table=<layout_versions>), Column('h20', INTEGER(), table=<layout_versions>), Column('h21', INTEGER(), table=<layout_versions>), Column('h22', INTEGER(), table=<layout_versions>), Column('h23', INTEGER(), table=<layout_versions>), Column('h24', INTEGER(), table=<layout_versions>), Column('h25', INTEGER(), table=<layout_versions>), Column('h26', INTEGER(), table=<layout_versions>), Column('h27', INTEGER(), table=<layout_versions>), schema=None)

# %%
courses.columns.items()
# Out:
# [('course_name',
#   Column('course_name', VARCHAR(), table=<courses>, primary_key=True, nullable=False))]

# %%
scoredata
# Out:
# Table('scoredata', MetaData(), Column('course_name', VARCHAR(), ForeignKey('layout_versions.course_name'), table=<scoredata>, primary_key=True, nullable=False), Column('layout_name', VARCHAR(), ForeignKey('layout_versions.layout_name'), table=<scoredata>, primary_key=True, nullable=False), Column('layout_version', INTEGER(), ForeignKey('layout_versions.version'), table=<scoredata>, primary_key=True, nullable=False), Column('player_name', VARCHAR(), table=<scoredata>, primary_key=True, nullable=False), Column('teamsize', INTEGER(), table=<scoredata>, primary_key=True, nullable=False), Column('date', VARCHAR(), table=<scoredata>, primary_key=True, nullable=False), Column('result', INTEGER(), table=<scoredata>), Column('h1', INTEGER(), table=<scoredata>), Column('h2', INTEGER(), table=<scoredata>), Column('h3', INTEGER(), table=<scoredata>), Column('h4', INTEGER(), table=<scoredata>), Column('h5', INTEGER(), table=<scoredata>), Column('h6', INTEGER(), table=<scoredata>), Column('h7', INTEGER(), table=<scoredata>), Column('h8', INTEGER(), table=<scoredata>), Column('h9', INTEGER(), table=<scoredata>), Column('h10', INTEGER(), table=<scoredata>), Column('h11', INTEGER(), table=<scoredata>), Column('h12', INTEGER(), table=<scoredata>), Column('h13', INTEGER(), table=<scoredata>), Column('h14', INTEGER(), table=<scoredata>), Column('h15', INTEGER(), table=<scoredata>), Column('h16', INTEGER(), table=<scoredata>), Column('h17', INTEGER(), table=<scoredata>), Column('h18', INTEGER(), table=<scoredata>), Column('h19', INTEGER(), table=<scoredata>), Column('h20', INTEGER(), table=<scoredata>), Column('h21', INTEGER(), table=<scoredata>), Column('h22', INTEGER(), table=<scoredata>), Column('h23', INTEGER(), table=<scoredata>), Column('h24', INTEGER(), table=<scoredata>), Column('h25', INTEGER(), table=<scoredata>), Column('h26', INTEGER(), table=<scoredata>), Column('h27', INTEGER(), table=<scoredata>), schema=None)

# %%
courses
# Out:
# Table('courses', MetaData(), Column('course_name', VARCHAR(), table=<courses>, primary_key=True, nullable=False), schema=None)
